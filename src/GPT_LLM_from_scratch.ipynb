# %%
file_path =  '/content/drive/MyDrive/colab_datas/small_llm/input.txt'

# %%
# Read the whole file as a single string
with open(file_path, 'r') as file:
    text = file.read()

print(text[:1000])

# %%
# unique chars in the text
chars = sorted(set(text))
vocab_size = len(chars)
print(''.join(chars))
print(vocab_size)
# Out:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# 65

# %%
# char to int mapping

stoi = {ch:i for i,ch in enumerate(chars)}
itos = {i:ch for i,ch in enumerate(chars)}
encode = lambda s: [stoi[c] for c in s] # encoder: takes string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a String


print(encode("hii there!"))
print(decode(encode("hii there!")))
# Out:
# [46, 47, 47, 1, 58, 46, 43, 56, 43, 2]
# hii there!

# %%
import torch
data = torch.tensor(encode(text), dtype = torch.long)

print(data.shape, data.dtype)
print(data[0:100])
# Out:
# torch.Size([1115394]) torch.int64
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39, 56,  1, 51, 43,  1,
#         57, 54, 43, 39, 49,  8,  0,  0, 13, 50, 50, 10,  0, 31, 54, 43, 39, 49,
#          6,  1, 57, 54, 43, 39, 49,  8,  0,  0, 18, 47, 56, 57, 58,  1, 15, 47,
#         58, 47, 64, 43, 52, 10,  0, 37, 53, 59])

# %%
# split data to train and validate dataset

n = int(0.9*len(data))
train_data = data[:n]
val_data = data[n:]

# %%
block_size = 8
train_data[:block_size+1]
# Out:
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58])

# %%
x = train_data[:block_size]
y = train_data[1:block_size+1]
for t in range(block_size):
  context = x[:t+1]
  target = y[t]
  print(f"input={context} taget={target}")
# Out:
# input=tensor([18]) taget=47
# input=tensor([18, 47]) taget=56
# input=tensor([18, 47, 56]) taget=57
# input=tensor([18, 47, 56, 57]) taget=58
# input=tensor([18, 47, 56, 57, 58]) taget=1
# input=tensor([18, 47, 56, 57, 58,  1]) taget=15
# input=tensor([18, 47, 56, 57, 58,  1, 15]) taget=47
# input=tensor([18, 47, 56, 57, 58,  1, 15, 47]) taget=58

# %%
torch.manual_seed(1337)
batch_size = 4 # no of independent seq to process in parallel
block_size = 8 # max context len for prediction

def get_batch(split):
  data = train_data if split == 'train' else val_data
  ix = torch.randint(len(data)-block_size, (batch_size,))
  x = torch.stack([data[i:i+block_size] for i in ix])
  y = torch.stack([data[i+1:i+block_size+1] for i in ix])
  return x,y

xb, yb = get_batch('train')
print('inputs:')
print(xb.shape)
print(xb)

print('targets:')
print(yb.shape)
print(yb)

print("-------")

for b in range(batch_size):
  for t in range(block_size):
    context = xb[b,:t+1]
    target = yb[b,t]
    print(f"input={context} taget={target}")
# Out:
# inputs:
# torch.Size([4, 8])
# tensor([[24, 43, 58,  5, 57,  1, 46, 43],
#         [44, 53, 56,  1, 58, 46, 39, 58],
#         [52, 58,  1, 58, 46, 39, 58,  1],
#         [25, 17, 27, 10,  0, 21,  1, 54]])
# targets:
# torch.Size([4, 8])
# tensor([[43, 58,  5, 57,  1, 46, 43, 39],
#         [53, 56,  1, 58, 46, 39, 58,  1],
#         [58,  1, 58, 46, 39, 58,  1, 46],
#         [17, 27, 10,  0, 21,  1, 54, 39]])
# -------
# input=tensor([24]) taget=43
# input=tensor([24, 43]) taget=58
# input=tensor([24, 43, 58]) taget=5
# input=tensor([24, 43, 58,  5]) taget=57
# input=tensor([24, 43, 58,  5, 57]) taget=1
# input=tensor([24, 43, 58,  5, 57,  1]) taget=46
# input=tensor([24, 43, 58,  5, 57,  1, 46]) taget=43
# input=tensor([24, 43, 58,  5, 57,  1, 46, 43]) taget=39
# input=tensor([44]) taget=53
# input=tensor([44, 53]) taget=56
# input=tensor([44, 53, 56]) taget=1
# input=tensor([44, 53, 56,  1]) taget=58
# input=tensor([44, 53, 56,  1, 58]) taget=46
# input=tensor([44, 53, 56,  1, 58, 46]) taget=39
# input=tensor([44, 53, 56,  1, 58, 46, 39]) taget=58
# input=tensor([44, 53, 56,  1, 58, 46, 39, 58]) taget=1
# input=tensor([52]) taget=58
# input=tensor([52, 58]) taget=1
# input=tensor([52, 58,  1]) taget=58
# input=tensor([52, 58,  1, 58]) taget=46
# input=tensor([52, 58,  1, 58, 46]) taget=39
# input=tensor([52, 58,  1, 58, 46, 39]) taget=58
# input=tensor([52, 58,  1, 58, 46, 39, 58]) taget=1
# input=tensor([52, 58,  1, 58, 46, 39, 58,  1]) taget=46
# input=tensor([25]) taget=17
# input=tensor([25, 17]) taget=27
# input=tensor([25, 17, 27]) taget=10
# input=tensor([25, 17, 27, 10]) taget=0
# input=tensor([25, 17, 27, 10,  0]) taget=21
# input=tensor([25, 17, 27, 10,  0, 21]) taget=1
# input=tensor([25, 17, 27, 10,  0, 21,  1]) taget=54
# input=tensor([25, 17, 27, 10,  0, 21,  1, 54]) taget=39

# %%
print(xb) # input to transformer
# Out:
# tensor([[24, 43, 58,  5, 57,  1, 46, 43],
#         [44, 53, 56,  1, 58, 46, 39, 58],
#         [52, 58,  1, 58, 46, 39, 58,  1],
#         [25, 17, 27, 10,  0, 21,  1, 54]])

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

torch.manual_seed(1337)

class BigramLanguageModel(nn.Module):
  def __init__(self,vocab_size):
    super().__init__()
    self.token_embedding_table  = nn.Embedding(vocab_size, vocab_size)

  def forward(self, idx, targets = None):
    logits = self.token_embedding_table(idx) # (B,T,C)

    if targets is None:
      loss = None
    else:
      B,T,C = logits.shape
      logits = logits.view(B*T,C)
      targets = targets.view(B*T)
      loss = F.cross_entropy(logits, targets)

    return logits,loss

  def generate(self, idx, max_new_tokens):
    for _ in range(max_new_tokens):
      logits, loss = self(idx)
      logits = logits[:, -1, :]
      probs = F.softmax(logits, dim = 1)
      idx_next = torch.multinomial(probs, num_samples = 1)
      idx = torch.cat((idx, idx_next), dim=1)
    return idx

m = BigramLanguageModel(vocab_size)
logits, loss = m(xb, yb)
print(logits.shape)
print(loss)

idx = torch.zeros((1,1), dtype=torch.long)
print(decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# torch.Size([32, 65])
# tensor(4.8786, grad_fn=<NllLossBackward0>)
#
# SKIcLT;AcELMoTbvZv C?nq-QE33:CJqkOKH-q;:la!oiywkHjgChzbQ?u!3bLIgwevmyFJGUGp
# wnYWmnxKWWev-tDqXErVKLgJ

# %%
# pyTorch optimizer
optimizer = torch.optim.AdamW(m.parameters(), lr=1e-3)

# %%
batch_size = 32
for i in range(16):
  for steps in range(1000):

    xb,yb = get_batch('train')

    logits,loss = m(xb,yb)
    optimizer.zero_grad(set_to_none = True)
    loss.backward()
    optimizer.step()

  print(loss.item())

# %%
idx = torch.zeros((1,1), dtype=torch.long)
print(decode(m.generate(idx, max_new_tokens=500)[0].tolist()))
# Out:
# Heofl go? be's my bermen we, E: a heawn?
#
#
# Wes int cowh abldave ancowad l sh.
#
#
# UClly.
# Wh
# 'de nd, aiut;
# Winghic
# Lot yod aucacat t y hen d s w?
# thouryor, che nin me whaineay f I ath s t'ly minos; bye
# LINothis eldin;
#
#
# Cotitree y m we KEEESes hi'laia at thiforleed, Brveyaced dot.
# CEORCLAnng.
# TI f'd; fedin thatho in, LAnd,
# CONGoous, hat fois ind, fouexe, t d bethaketeerus wisous. l hirler'sthalathe I's t mbe telame cashofr aimolilake, sindin faivendshe fikis h bonst shodladre IORGSTalestheeseag a

# %%
# !python3 /content/drive/MyDrive/colab_datas/small_llm/bigram.py
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You are all resolved rather to die than to famish?
#
# All:
# Resolved. resolved.
#
# First Citizen:
# First, you know Caius Marcius is chief enemy to the people.
#
# All:
# We know't, we know't.
#
# First Citizen:
# Let us kill him, and we'll have corn at our own price.
# Is't a verdict?
#
# All:
# No more talking on't; let it be done: away, away!
#
# Second Citizen:
# One word, good citizens.
#
# First Citizen:
# We are accounted poor citizens, the patricians good.
# What authority surfeits on would relieve us: if they
# would yield us but the superfluity, while it were
# wholesome, we might guess they relieved us humanely;
# but they think we are too dear: the leanness that
# afflicts us, the object of our misery, is as an
# inventory to particularise their abundance; our
# sufferance is a gain to them Let us revenge this with
# our pikes, ere we become rakes: for the gods know I
# speak this in hunger for bread, not in thirst for revenge.
#
#
#
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# 65
# [46, 47, 47, 1, 58, 46, 43, 56, 43, 2]
# hii there!
# torch.Size([1115394]) torch.int64
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39, 56,  1, 51, 43,  1,
#         57, 54, 43, 39, 49,  8,  0,  0, 13, 50, 50, 10,  0, 31, 54, 43, 39, 49,
#          6,  1, 57, 54, 43, 39, 49,  8,  0,  0, 18, 47, 56, 57, 58,  1, 15, 47,
#         58, 47, 64, 43, 52, 10,  0, 37, 53, 59])
# input=tensor([18]) taget=47
# input=tensor([18, 47]) taget=56
# input=tensor([18, 47, 56]) taget=57
# input=tensor([18, 47, 56, 57]) taget=58
# input=tensor([18, 47, 56, 57, 58]) taget=1
# input=tensor([18, 47, 56, 57, 58,  1]) taget=15
# input=tensor([18, 47, 56, 57, 58,  1, 15]) taget=47
# input=tensor([18, 47, 56, 57, 58,  1, 15, 47]) taget=58
# inputs:
# torch.Size([4, 8])
# tensor([[24, 43, 58,  5, 57,  1, 46, 43],
#         [44, 53, 56,  1, 58, 46, 39, 58],
#         [52, 58,  1, 58, 46, 39, 58,  1],
#         [25, 17, 27, 10,  0, 21,  1, 54]])
# targets:
# torch.Size([4, 8])
# tensor([[43, 58,  5, 57,  1, 46, 43, 39],
#         [53, 56,  1, 58, 46, 39, 58,  1],
#         [58,  1, 58, 46, 39, 58,  1, 46],
#         [17, 27, 10,  0, 21,  1, 54, 39]])
# -------
# input=tensor([24]) taget=43
# input=tensor([24, 43]) taget=58
# input=tensor([24, 43, 58]) taget=5
# input=tensor([24, 43, 58,  5]) taget=57
# input=tensor([24, 43, 58,  5, 57]) taget=1
# input=tensor([24, 43, 58,  5, 57,  1]) taget=46
# input=tensor([24, 43, 58,  5, 57,  1, 46]) taget=43
# input=tensor([24, 43, 58,  5, 57,  1, 46, 43]) taget=39
# input=tensor([44]) taget=53
# input=tensor([44, 53]) taget=56
# input=tensor([44, 53, 56]) taget=1
# input=tensor([44, 53, 56,  1]) taget=58
# input=tensor([44, 53, 56,  1, 58]) taget=46
# input=tensor([44, 53, 56,  1, 58, 46]) taget=39
# input=tensor([44, 53, 56,  1, 58, 46, 39]) taget=58
# input=tensor([44, 53, 56,  1, 58, 46, 39, 58]) taget=1
# input=tensor([52]) taget=58
# input=tensor([52, 58]) taget=1
# input=tensor([52, 58,  1]) taget=58
# input=tensor([52, 58,  1, 58]) taget=46
# input=tensor([52, 58,  1, 58, 46]) taget=39
# input=tensor([52, 58,  1, 58, 46, 39]) taget=58
# input=tensor([52, 58,  1, 58, 46, 39, 58]) taget=1
# input=tensor([52, 58,  1, 58, 46, 39, 58,  1]) taget=46
# input=tensor([25]) taget=17
# input=tensor([25, 17]) taget=27
# input=tensor([25, 17, 27]) taget=10
# input=tensor([25, 17, 27, 10]) taget=0
# input=tensor([25, 17, 27, 10,  0]) taget=21
# input=tensor([25, 17, 27, 10,  0, 21]) taget=1
# input=tensor([25, 17, 27, 10,  0, 21,  1]) taget=54
# input=tensor([25, 17, 27, 10,  0, 21,  1, 54]) taget=39
# tensor([[24, 43, 58,  5, 57,  1, 46, 43],
#         [44, 53, 56,  1, 58, 46, 39, 58],
#         [52, 58,  1, 58, 46, 39, 58,  1],
#         [25, 17, 27, 10,  0, 21,  1, 54]])
# torch.Size([32, 65])
# tensor(4.8786, grad_fn=<NllLossBackward0>)
#
# SKIcLT;AcELMoTbvZv C?nq-QE33:CJqkOKH-q;:la!oiywkHjgChzbQ?u!3bLIgwevmyFJGUGp
# wnYWmnxKWWev-tDqXErVKLgJ
# 3.704136610031128
# 3.106309175491333
# 2.896475315093994
# 2.554206609725952
# 2.536130905151367
# 2.6574454307556152
# 2.4518814086914062
# 2.425344228744507
# 2.2895455360412598
# 2.382369041442871
# 2.580815315246582
# 2.4362940788269043
# 2.4405882358551025
# 2.547163486480713
# 2.413579225540161
# 2.3514575958251953
#
# Yobuthoerpe ow t, hak;
#
#
# TERUEr:
# I RW:
# TEvichees tr st ad; as t mesisheg bor mear.
# Be.
# Sin ch wo ay manchithyo'tlordinghond me scan'eat: maver d p. h,
# Fowou he he ay maurer l man.
# Awosthan, pl ainsar rethany ur INVatrild wethe hano heato wizesat. hifeas, r atheasave l;
# KI im her thyouthif aresee
# Toues wimy ERYort s fe dothag windd?
# Theman y quer n, rke!
# Ammeeld IORMORDI rere illeathe I; nasugode w t MIS: wibacit e m moorn me bathendwhot
# DWhol, 'd be f pard h dimak, Cale rodes I ferdou.
# Whay;
# ORK

# %%
torch.manual_seed(1337)
B,T,C = 4,8,2
x = torch.randn(B,T,C)
x.shape
# Out:
# torch.Size([4, 8, 2])

# %%
# x[b,t] = mean_{i<=t} x[b,i]
xbow = torch.zeros(B,T,C)
for b in range(B):
  for t in range(T):
    xprev = x[b,:t+1] # (t,c)
    xbow[b,t] = torch.mean(xprev,0)

# %%
#version 2
wei = torch.tril(torch.ones(T,T))
wei = wei / wei.sum(1,keepdim=True)
xbow2 = wei @ x # (B,T,T) @ (B,T,C) --------> (B,T,C)
torch.allclose(xbow,xbow2)
# Out:
# False

# %%
#version 3: use softmax
tril = torch.tril(torch.ones(T,T))
wei = torch.zeros((T,T))
wei = wei.masked_fill(tril == 0, float('-inf'))
wei = F.softmax(wei, dim=1)
xbow2 = wei @ x # (B,T,T) @ (B,T,C) --------> (B,T,C)
torch.allclose(xbow,xbow2)
# Out:
# False

# %%
#version 4: use self-attention
torch.manual_seed(1337)
B,T,C = 4,8,32
x= torch.randn(B,T,C)

# single Head perform self-attention
head_size = 16
key = nn.Linear(C, head_size, bias = False)
query = nn.Linear(C, head_size, bias = False)
value = nn.Linear(C, head_size, bias = False)

k = key(x) # (B, T, 16)
q = query(x) # (B, T, 16)

wei = q @ k.transpose(-2,-1) # * head_size **-0.5 # (B,T,16) @ (B,16,T) ---> (B, T, T)

tril = torch.tril(torch.ones(T,T))
#wei = torch.zeros((T,T))
wei = wei.masked_fill(tril == 0, float('-inf'))
wei = F.softmax(wei, dim=1)

v = value(x)
out = wei @ v
#out = wei @ x # (B,T,T) @ (B,T,C) --------> (B,T,C)

out.shape
# torch.allclose(xbow,xbow2)
# Out:
# torch.Size([4, 8, 16])

# %%
wei[0]
# Out:
# tensor([[0.0248, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0052, 0.0091, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0521, 0.0135, 0.2482, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3171, 0.0214, 0.1642, 0.1188, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0412, 0.0487, 0.1046, 0.0742, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1060, 0.5347, 0.2059, 0.1030, 0.7402, 0.0192, 0.0000, 0.0000],
#         [0.4298, 0.3409, 0.1769, 0.2027, 0.0480, 0.8472, 0.2329, 0.0000],
#         [0.0238, 0.0316, 0.1002, 0.5013, 0.0117, 0.1336, 0.7671, 1.0000]],
#        grad_fn=<SelectBackward0>)

# %%
xbow[0],xbow2[0],xbow.shape,xbow2.shape
# Out:
# (tensor([[ 0.1808, -0.0700],
#          [-0.0894, -0.4926],
#          [ 0.1490, -0.3199],
#          [ 0.3504, -0.2238],
#          [ 0.3525,  0.0545],
#          [ 0.0688, -0.0396],
#          [ 0.0927, -0.0682],
#          [-0.0341,  0.1332]]),
#  tensor([[ 0.1808, -0.0700],
#          [-0.0894, -0.4926],
#          [ 0.1490, -0.3199],
#          [ 0.3504, -0.2238],
#          [ 0.3525,  0.0545],
#          [ 0.0688, -0.0396],
#          [ 0.0927, -0.0682],
#          [-0.0341,  0.1332]]),
#  torch.Size([4, 8, 2]),
#  torch.Size([4, 8, 2]))

# %%
# !python3 /content/drive/MyDrive/colab_datas/small_llm/bigram2.py

# %%
# !python3 /content/drive/MyDrive/colab_datas/small_llm/v2.py

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

#hyper params
batch_size = 32 # no of independent seq to process in parallel
block_size = 64 # def 8,  max context len for prediction
max_iters = 25000
eval_interval = 1000
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embed = 32



file_path =  '/content/drive/MyDrive/colab_datas/small_llm/input.txt'

# Read the whole file as a single string
with open(file_path, 'r') as file:
    text = file.read()

print(text[:1000])



# unique chars in the text
chars = sorted(set(text))
vocab_size = len(chars)
print(''.join(chars))
print(vocab_size)


# char to int mapping
stoi = {ch:i for i,ch in enumerate(chars)}
itos = {i:ch for i,ch in enumerate(chars)}
encode = lambda s: [stoi[c] for c in s] # encoder: takes string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a String

print(encode("hii there!"))
print(decode(encode("hii there!")))

#create tensor from text
data = torch.tensor(encode(text), dtype = torch.long)
print(data.shape, data.dtype)
print(data[0:100])

# split data to train and validate dataset
n = int(0.9*len(data))
train_data = data[:n]
val_data = data[n:]


block_size = 8
train_data[:block_size+1]

x = train_data[:block_size]
y = train_data[1:block_size+1]
for t in range(block_size):
  context = x[:t+1]
  target = y[t]
  print(f"input={context} taget={target}")


##
torch.manual_seed(1337)

def get_batch(split):
  data = train_data if split == 'train' else val_data
  ix = torch.randint(len(data)-block_size, (batch_size,))
  x = torch.stack([data[i:i+block_size] for i in ix])
  y = torch.stack([data[i+1:i+block_size+1] for i in ix])

  x,y = x.to(device),y.to(device)

  return x,y

xb, yb = get_batch('train')
print('inputs:')
print(xb.shape)
print(xb)

print('targets:')
print(yb.shape)
print(yb)

print("-------")

for b in range(batch_size):
  for t in range(block_size):
    context = xb[b,:t+1]
    target = yb[b,t]
    print(f"input={context} taget={target}")

print(xb) # input to transformer

## eval loss
@torch.no_grad()
def estimate_loss():
  out = {}
  model.eval()
  for split in ['train', 'val']:
    losses = torch.zeros(eval_iters)
    for k in range(eval_iters):
      x,y = get_batch(split)
      logits, loss = model(x,y)
      losses[k] = loss.item()
    out[split] = losses.mean()
  model.train()
  return out


##

torch.manual_seed(1337)


class Head(nn.Module):
  def __init__(self, head_size):
    super().__init__()
    self.key = nn.Linear(n_embed, head_size, bias = False)
    self.query = nn.Linear(n_embed, head_size, bias = False)
    self.value = nn.Linear(n_embed, head_size, bias = False)
    self.register_buffer('tril',torch.tril(torch.ones(block_size, block_size)))

  def forward(self, x):
    B,T,C = x.shape
    k = self.key(x)
    q = self.query(x)

    wei = q @ k.transpose(-2,-1) * C**-0.5
    wei = wei.masked_fill(self.tril[:T,:T]==0, float('-inf'))
    wei = F.softmax(wei, dim=-1)

    v = self.value(x)
    out = wei @ v
    return out

class MultiHeadAttention(nn.Module):
  def __init__(self, num_heads, head_size):
    super().__init__()
    self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])

  def forward(self, x):
    return torch.cat([h(x) for h in self.heads], dim=-1)

class FeedForward(nn.Module):
  def __init__(self, n_embed):
    super().__init__()
    self.net = nn.Sequential(
      nn.Linear(n_embed, n_embed),
      nn.ReLU(),
    )

  def forward(self, x):
    return self.net(x)

class BigramLanguageModel(nn.Module):
  def __init__(self):
    super().__init__()
    self.token_embedding_table  = nn.Embedding(vocab_size, n_embed)
    self.position_embedding_table = nn.Embedding(block_size, n_embed)
    #self.sa_head = Head(n_embed)
    self.sa_heads = MultiHeadAttention(4,n_embed//4)
    self.ffwd = FeedForward(n_embed)
    self.lm_head = nn.Linear(n_embed, vocab_size)

  def forward(self, idx, targets = None):
    B,T = idx.shape
    # logits = self.token_embedding_table(idx) # (B,T,C)
    token_emb = self.token_embedding_table(idx) # (B,T,C)
    pos_emb = self.position_embedding_table(torch.arange(T, device=device)) #(T,C)
    x = token_emb + pos_emb
    #x = self.sa_head(x)
    x = self.sa_heads(x)
    x = self.ffwd(x)
    logits = self.lm_head(x) # (B,T,C=vocab size)


    if targets is None:
      loss = None
    else:
      B,T,C = logits.shape
      logits = logits.view(B*T,C)
      targets = targets.view(B*T)
      loss = F.cross_entropy(logits, targets)

    return logits,loss

  def generate(self, idx, max_new_tokens):
    for _ in range(max_new_tokens):
      idx_cond = idx[:,-block_size:]
      logits, loss = self(idx_cond)
      logits = logits[:, -1, :]
      probs = F.softmax(logits, dim = 1)
      idx_next = torch.multinomial(probs, num_samples = 1)
      idx = torch.cat((idx, idx_next), dim=1)
    return idx

model = BigramLanguageModel()
m = model.to(device)
logits, loss = model(xb, yb)
print(logits.shape)
print(loss)

# idx = torch.zeros((1,1), dtype=torch.long)
# print(decode(model.generate(idx, max_new_tokens=100)[0].tolist()))

# pyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

# train
for i in range(max_iters):
  if i % eval_interval ==0:
    losses = estimate_loss()
    print(f"step {i}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

  xb,yb = get_batch('train')
  # xb.to(device)
  # yb.to(device)
  logits,loss = model(xb,yb)
  optimizer.zero_grad(set_to_none = True)
  loss.backward()
  optimizer.step()

  #print(loss.item())


#generate
context = torch.zeros((1,1), dtype=torch.long, device = device)
print(decode(model.generate(context, max_new_tokens=200)[0].tolist()))
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You are all resolved rather to die than to famish?
#
# All:
# Resolved. resolved.
#
# First Citizen:
# First, you know Caius Marcius is chief enemy to the people.
#
# All:
# We know't, we know't.
#
# First Citizen:
# Let us kill him, and we'll have corn at our own price.
# Is't a verdict?
#
# All:
# No more talking on't; let it be done: away, away!
#
# Second Citizen:
# One word, good citizens.
#
# First Citizen:
# We are accounted poor citizens, the patricians good.
# What authority surfeits on would relieve us: if they
# would yield us but the superfluity, while it were
# wholesome, we might guess they relieved us humanely;
# but they think we are too dear: the leanness that
# afflicts us, the object of our misery, is as an
# inventory to particularise their abundance; our
# sufferance is a gain to them Let us revenge this with
# our pikes, ere we become rakes: for the gods know I
# speak this in hunger for bread, not in thirst for revenge.
#
#
#
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# 65
# [46, 47, 47, 1, 58, 46, 43, 56, 43, 2]
# hii there!
# torch.Size([1115394]) torch.int64
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39, 56,  1, 51, 43,  1,
#         57, 54, 43, 39, 49,  8,  0,  0, 13, 50, 50, 10,  0, 31, 54, 43, 39, 49,
#          6,  1, 57, 54, 43, 39, 49,  8,  0,  0, 18, 47, 56, 57, 58,  1, 15, 47,
#         58, 47, 64, 43, 52, 10,  0, 37, 53, 59])
# input=tensor([18]) taget=47
# input=tensor([18, 47]) taget=56
# input=tensor([18, 47, 56]) taget=57
# input=tensor([18, 47, 56, 57]) taget=58
# input=tensor([18, 47, 56, 57, 58]) taget=1
# input=tensor([18, 47, 56, 57, 58,  1]) taget=15
# input=tensor([18, 47, 56, 57, 58,  1, 15]) taget=47
# input=tensor([18, 47, 56, 57, 58,  1, 15, 47]) taget=58
# inputs:
# torch.Size([32, 8])
# tensor([[24, 43, 58,  5, 57,  1, 46, 43],
#         [44, 53, 56,  1, 58, 46, 39, 58],
#         [52, 58,  1, 58, 46, 39, 58,  1],
#         [25, 17, 27, 10,  0, 21,  1, 54],
#         [57, 43, 60, 43, 52,  1, 63, 43],
#         [60, 43, 42,  8,  0, 25, 63,  1],
#         [56, 42,  5, 57,  1, 57, 39, 49],
#         [43, 57, 58, 63,  6,  1, 58, 46],
#         [43,  1, 51, 39, 63,  1, 40, 43],
#         [58, 46, 43,  1, 43, 39, 56, 57],
#         [39, 58, 47, 53, 52, 12,  1, 37],
#         [53, 56, 43,  1, 21,  1, 41, 39],
#         [50, 39, 52, 63,  1, 47, 58, 57],
#         [56, 53, 63,  1, 42, 47, 42,  1],
#         [39, 51,  1, 39, 44, 56, 39, 47],
#         [17, 24, 21, 38, 13, 14, 17, 32],
#         [ 1, 39, 52, 42,  1, 45, 43, 50],
#         [ 1, 58, 46, 39, 58,  1, 42, 53],
#         [ 1, 61, 53, 59, 50, 42,  1, 21],
#         [59, 57, 40, 39, 52, 42,  1, 40],
#         [52, 42,  8,  0,  0, 23, 21, 26],
#         [45, 53, 42, 57,  0, 23, 43, 43],
#         [52,  1, 61, 39, 57,  1, 51, 53],
#         [39, 49, 12,  1, 27,  1, 58, 56],
#         [53, 44,  1, 57, 54, 43, 43, 41],
#         [57, 53, 52, 57,  8,  0,  0, 25],
#         [ 1, 42, 43, 44, 43, 41, 58,  1],
#         [21,  1, 61, 39, 52, 42, 43, 56],
#         [43, 43, 51,  5, 42,  1, 40, 59],
#         [45, 50, 63,  1, 52, 53, 61, 12],
#         [52, 53, 58,  8,  0, 25, 63,  1],
#         [53, 58,  6,  1, 51, 63,  1, 50]])
# targets:
# torch.Size([32, 8])
# tensor([[43, 58,  5, 57,  1, 46, 43, 39],
#         [53, 56,  1, 58, 46, 39, 58,  1],
#         [58,  1, 58, 46, 39, 58,  1, 46],
#         [17, 27, 10,  0, 21,  1, 54, 39],
#         [43, 60, 43, 52,  1, 63, 43, 39],
#         [43, 42,  8,  0, 25, 63,  1, 45],
#         [42,  5, 57,  1, 57, 39, 49, 43],
#         [57, 58, 63,  6,  1, 58, 46, 47],
#         [ 1, 51, 39, 63,  1, 40, 43,  1],
#         [46, 43,  1, 43, 39, 56, 57, 10],
#         [58, 47, 53, 52, 12,  1, 37, 53],
#         [56, 43,  1, 21,  1, 41, 39, 51],
#         [39, 52, 63,  1, 47, 58, 57, 43],
#         [53, 63,  1, 42, 47, 42,  1, 57],
#         [51,  1, 39, 44, 56, 39, 47, 42],
#         [24, 21, 38, 13, 14, 17, 32, 20],
#         [39, 52, 42,  1, 45, 43, 50, 42],
#         [58, 46, 39, 58,  1, 42, 53,  1],
#         [61, 53, 59, 50, 42,  1, 21,  1],
#         [57, 40, 39, 52, 42,  1, 40, 47],
#         [42,  8,  0,  0, 23, 21, 26, 19],
#         [53, 42, 57,  0, 23, 43, 43, 54],
#         [ 1, 61, 39, 57,  1, 51, 53, 56],
#         [49, 12,  1, 27,  1, 58, 56, 39],
#         [44,  1, 57, 54, 43, 43, 41, 46],
#         [53, 52, 57,  8,  0,  0, 25, 17],
#         [42, 43, 44, 43, 41, 58,  1, 53],
#         [ 1, 61, 39, 52, 42, 43, 56,  6],
#         [43, 51,  5, 42,  1, 40, 59, 56],
#         [50, 63,  1, 52, 53, 61, 12,  0],
#         [53, 58,  8,  0, 25, 63,  1, 61],
#         [58,  6,  1, 51, 63,  1, 50, 53]])
# -------
# input=tensor([24]) taget=43
# input=tensor([24, 43]) taget=58
# input=tensor([24, 43, 58]) taget=5
# input=tensor([24, 43, 58,  5]) taget=57
# input=tensor([24, 43, 58,  5, 57]) taget=1
# input=tensor([24, 43, 58,  5, 57,  1]) taget=46
# input=tensor([24, 43, 58,  5, 57,  1, 46]) taget=43
# input=tensor([24, 43, 58,  5, 57,  1, 46, 43]) taget=39
# input=tensor([44]) taget=53
# input=tensor([44, 53]) taget=56
# input=tensor([44, 53, 56]) taget=1
# input=tensor([44, 53, 56,  1]) taget=58
# input=tensor([44, 53, 56,  1, 58]) taget=46
# input=tensor([44, 53, 56,  1, 58, 46]) taget=39
# input=tensor([44, 53, 56,  1, 58, 46, 39]) taget=58
# input=tensor([44, 53, 56,  1, 58, 46, 39, 58]) taget=1
# input=tensor([52]) taget=58
# input=tensor([52, 58]) taget=1
# input=tensor([52, 58,  1]) taget=58
# input=tensor([52, 58,  1, 58]) taget=46
# input=tensor([52, 58,  1, 58, 46]) taget=39
# input=tensor([52, 58,  1, 58, 46, 39]) taget=58
# input=tensor([52, 58,  1, 58, 46, 39, 58]) taget=1
# input=tensor([52, 58,  1, 58, 46, 39, 58,  1]) taget=46
# input=tensor([25]) taget=17
# input=tensor([25, 17]) taget=27
# input=tensor([25, 17, 27]) taget=10
# input=tensor([25, 17, 27, 10]) taget=0
# input=tensor([25, 17, 27, 10,  0]) taget=21
# input=tensor([25, 17, 27, 10,  0, 21]) taget=1
# input=tensor([25, 17, 27, 10,  0, 21,  1]) taget=54
# input=tensor([25, 17, 27, 10,  0, 21,  1, 54]) taget=39
# input=tensor([57]) taget=43
# input=tensor([57, 43]) taget=60
# input=tensor([57, 43, 60]) taget=43
# input=tensor([57, 43, 60, 43]) taget=52
# input=tensor([57, 43, 60, 43, 52]) taget=1
# input=tensor([57, 43, 60, 43, 52,  1]) taget=63
# input=tensor([57, 43, 60, 43, 52,  1, 63]) taget=43
# input=tensor([57, 43, 60, 43, 52,  1, 63, 43]) taget=39
# input=tensor([60]) taget=43
# input=tensor([60, 43]) taget=42
# input=tensor([60, 43, 42]) taget=8
# input=tensor([60, 43, 42,  8]) taget=0
# input=tensor([60, 43, 42,  8,  0]) taget=25
# input=tensor([60, 43, 42,  8,  0, 25]) taget=63
# input=tensor([60, 43, 42,  8,  0, 25, 63]) taget=1
# input=tensor([60, 43, 42,  8,  0, 25, 63,  1]) taget=45
# input=tensor([56]) taget=42
# input=tensor([56, 42]) taget=5
# input=tensor([56, 42,  5]) taget=57
# input=tensor([56, 42,  5, 57]) taget=1
# input=tensor([56, 42,  5, 57,  1]) taget=57
# input=tensor([56, 42,  5, 57,  1, 57]) taget=39
# input=tensor([56, 42,  5, 57,  1, 57, 39]) taget=49
# input=tensor([56, 42,  5, 57,  1, 57, 39, 49]) taget=43
# input=tensor([43]) taget=57
# input=tensor([43, 57]) taget=58
# input=tensor([43, 57, 58]) taget=63
# input=tensor([43, 57, 58, 63]) taget=6
# input=tensor([43, 57, 58, 63,  6]) taget=1
# input=tensor([43, 57, 58, 63,  6,  1]) taget=58
# input=tensor([43, 57, 58, 63,  6,  1, 58]) taget=46
# input=tensor([43, 57, 58, 63,  6,  1, 58, 46]) taget=47
# input=tensor([43]) taget=1
# input=tensor([43,  1]) taget=51
# input=tensor([43,  1, 51]) taget=39
# input=tensor([43,  1, 51, 39]) taget=63
# input=tensor([43,  1, 51, 39, 63]) taget=1
# input=tensor([43,  1, 51, 39, 63,  1]) taget=40
# input=tensor([43,  1, 51, 39, 63,  1, 40]) taget=43
# input=tensor([43,  1, 51, 39, 63,  1, 40, 43]) taget=1
# input=tensor([58]) taget=46
# input=tensor([58, 46]) taget=43
# input=tensor([58, 46, 43]) taget=1
# input=tensor([58, 46, 43,  1]) taget=43
# input=tensor([58, 46, 43,  1, 43]) taget=39
# input=tensor([58, 46, 43,  1, 43, 39]) taget=56
# input=tensor([58, 46, 43,  1, 43, 39, 56]) taget=57
# input=tensor([58, 46, 43,  1, 43, 39, 56, 57]) taget=10
# input=tensor([39]) taget=58
# input=tensor([39, 58]) taget=47
# input=tensor([39, 58, 47]) taget=53
# input=tensor([39, 58, 47, 53]) taget=52
# input=tensor([39, 58, 47, 53, 52]) taget=12
# input=tensor([39, 58, 47, 53, 52, 12]) taget=1
# input=tensor([39, 58, 47, 53, 52, 12,  1]) taget=37
# input=tensor([39, 58, 47, 53, 52, 12,  1, 37]) taget=53
# input=tensor([53]) taget=56
# input=tensor([53, 56]) taget=43
# input=tensor([53, 56, 43]) taget=1
# input=tensor([53, 56, 43,  1]) taget=21
# input=tensor([53, 56, 43,  1, 21]) taget=1
# input=tensor([53, 56, 43,  1, 21,  1]) taget=41
# input=tensor([53, 56, 43,  1, 21,  1, 41]) taget=39
# input=tensor([53, 56, 43,  1, 21,  1, 41, 39]) taget=51
# input=tensor([50]) taget=39
# input=tensor([50, 39]) taget=52
# input=tensor([50, 39, 52]) taget=63
# input=tensor([50, 39, 52, 63]) taget=1
# input=tensor([50, 39, 52, 63,  1]) taget=47
# input=tensor([50, 39, 52, 63,  1, 47]) taget=58
# input=tensor([50, 39, 52, 63,  1, 47, 58]) taget=57
# input=tensor([50, 39, 52, 63,  1, 47, 58, 57]) taget=43
# input=tensor([56]) taget=53
# input=tensor([56, 53]) taget=63
# input=tensor([56, 53, 63]) taget=1
# input=tensor([56, 53, 63,  1]) taget=42
# input=tensor([56, 53, 63,  1, 42]) taget=47
# input=tensor([56, 53, 63,  1, 42, 47]) taget=42
# input=tensor([56, 53, 63,  1, 42, 47, 42]) taget=1
# input=tensor([56, 53, 63,  1, 42, 47, 42,  1]) taget=57
# input=tensor([39]) taget=51
# input=tensor([39, 51]) taget=1
# input=tensor([39, 51,  1]) taget=39
# input=tensor([39, 51,  1, 39]) taget=44
# input=tensor([39, 51,  1, 39, 44]) taget=56
# input=tensor([39, 51,  1, 39, 44, 56]) taget=39
# input=tensor([39, 51,  1, 39, 44, 56, 39]) taget=47
# input=tensor([39, 51,  1, 39, 44, 56, 39, 47]) taget=42
# input=tensor([17]) taget=24
# input=tensor([17, 24]) taget=21
# input=tensor([17, 24, 21]) taget=38
# input=tensor([17, 24, 21, 38]) taget=13
# input=tensor([17, 24, 21, 38, 13]) taget=14
# input=tensor([17, 24, 21, 38, 13, 14]) taget=17
# input=tensor([17, 24, 21, 38, 13, 14, 17]) taget=32
# input=tensor([17, 24, 21, 38, 13, 14, 17, 32]) taget=20
# input=tensor([1]) taget=39
# input=tensor([ 1, 39]) taget=52
# input=tensor([ 1, 39, 52]) taget=42
# input=tensor([ 1, 39, 52, 42]) taget=1
# input=tensor([ 1, 39, 52, 42,  1]) taget=45
# input=tensor([ 1, 39, 52, 42,  1, 45]) taget=43
# input=tensor([ 1, 39, 52, 42,  1, 45, 43]) taget=50
# input=tensor([ 1, 39, 52, 42,  1, 45, 43, 50]) taget=42
# input=tensor([1]) taget=58
# input=tensor([ 1, 58]) taget=46
# input=tensor([ 1, 58, 46]) taget=39
# input=tensor([ 1, 58, 46, 39]) taget=58
# input=tensor([ 1, 58, 46, 39, 58]) taget=1
# input=tensor([ 1, 58, 46, 39, 58,  1]) taget=42
# input=tensor([ 1, 58, 46, 39, 58,  1, 42]) taget=53
# input=tensor([ 1, 58, 46, 39, 58,  1, 42, 53]) taget=1
# input=tensor([1]) taget=61
# input=tensor([ 1, 61]) taget=53
# input=tensor([ 1, 61, 53]) taget=59
# input=tensor([ 1, 61, 53, 59]) taget=50
# input=tensor([ 1, 61, 53, 59, 50]) taget=42
# input=tensor([ 1, 61, 53, 59, 50, 42]) taget=1
# input=tensor([ 1, 61, 53, 59, 50, 42,  1]) taget=21
# input=tensor([ 1, 61, 53, 59, 50, 42,  1, 21]) taget=1
# input=tensor([59]) taget=57
# input=tensor([59, 57]) taget=40
# input=tensor([59, 57, 40]) taget=39
# input=tensor([59, 57, 40, 39]) taget=52
# input=tensor([59, 57, 40, 39, 52]) taget=42
# input=tensor([59, 57, 40, 39, 52, 42]) taget=1
# input=tensor([59, 57, 40, 39, 52, 42,  1]) taget=40
# input=tensor([59, 57, 40, 39, 52, 42,  1, 40]) taget=47
# input=tensor([52]) taget=42
# input=tensor([52, 42]) taget=8
# input=tensor([52, 42,  8]) taget=0
# input=tensor([52, 42,  8,  0]) taget=0
# input=tensor([52, 42,  8,  0,  0]) taget=23
# input=tensor([52, 42,  8,  0,  0, 23]) taget=21
# input=tensor([52, 42,  8,  0,  0, 23, 21]) taget=26
# input=tensor([52, 42,  8,  0,  0, 23, 21, 26]) taget=19
# input=tensor([45]) taget=53
# input=tensor([45, 53]) taget=42
# input=tensor([45, 53, 42]) taget=57
# input=tensor([45, 53, 42, 57]) taget=0
# input=tensor([45, 53, 42, 57,  0]) taget=23
# input=tensor([45, 53, 42, 57,  0, 23]) taget=43
# input=tensor([45, 53, 42, 57,  0, 23, 43]) taget=43
# input=tensor([45, 53, 42, 57,  0, 23, 43, 43]) taget=54
# input=tensor([52]) taget=1
# input=tensor([52,  1]) taget=61
# input=tensor([52,  1, 61]) taget=39
# input=tensor([52,  1, 61, 39]) taget=57
# input=tensor([52,  1, 61, 39, 57]) taget=1
# input=tensor([52,  1, 61, 39, 57,  1]) taget=51
# input=tensor([52,  1, 61, 39, 57,  1, 51]) taget=53
# input=tensor([52,  1, 61, 39, 57,  1, 51, 53]) taget=56
# input=tensor([39]) taget=49
# input=tensor([39, 49]) taget=12
# input=tensor([39, 49, 12]) taget=1
# input=tensor([39, 49, 12,  1]) taget=27
# input=tensor([39, 49, 12,  1, 27]) taget=1
# input=tensor([39, 49, 12,  1, 27,  1]) taget=58
# input=tensor([39, 49, 12,  1, 27,  1, 58]) taget=56
# input=tensor([39, 49, 12,  1, 27,  1, 58, 56]) taget=39
# input=tensor([53]) taget=44
# input=tensor([53, 44]) taget=1
# input=tensor([53, 44,  1]) taget=57
# input=tensor([53, 44,  1, 57]) taget=54
# input=tensor([53, 44,  1, 57, 54]) taget=43
# input=tensor([53, 44,  1, 57, 54, 43]) taget=43
# input=tensor([53, 44,  1, 57, 54, 43, 43]) taget=41
# input=tensor([53, 44,  1, 57, 54, 43, 43, 41]) taget=46
# input=tensor([57]) taget=53
# input=tensor([57, 53]) taget=52
# input=tensor([57, 53, 52]) taget=57
# input=tensor([57, 53, 52, 57]) taget=8
# input=tensor([57, 53, 52, 57,  8]) taget=0
# input=tensor([57, 53, 52, 57,  8,  0]) taget=0
# input=tensor([57, 53, 52, 57,  8,  0,  0]) taget=25
# input=tensor([57, 53, 52, 57,  8,  0,  0, 25]) taget=17
# input=tensor([1]) taget=42
# input=tensor([ 1, 42]) taget=43
# input=tensor([ 1, 42, 43]) taget=44
# input=tensor([ 1, 42, 43, 44]) taget=43
# input=tensor([ 1, 42, 43, 44, 43]) taget=41
# input=tensor([ 1, 42, 43, 44, 43, 41]) taget=58
# input=tensor([ 1, 42, 43, 44, 43, 41, 58]) taget=1
# input=tensor([ 1, 42, 43, 44, 43, 41, 58,  1]) taget=53
# input=tensor([21]) taget=1
# input=tensor([21,  1]) taget=61
# input=tensor([21,  1, 61]) taget=39
# input=tensor([21,  1, 61, 39]) taget=52
# input=tensor([21,  1, 61, 39, 52]) taget=42
# input=tensor([21,  1, 61, 39, 52, 42]) taget=43
# input=tensor([21,  1, 61, 39, 52, 42, 43]) taget=56
# input=tensor([21,  1, 61, 39, 52, 42, 43, 56]) taget=6
# input=tensor([43]) taget=43
# input=tensor([43, 43]) taget=51
# input=tensor([43, 43, 51]) taget=5
# input=tensor([43, 43, 51,  5]) taget=42
# input=tensor([43, 43, 51,  5, 42]) taget=1
# input=tensor([43, 43, 51,  5, 42,  1]) taget=40
# input=tensor([43, 43, 51,  5, 42,  1, 40]) taget=59
# input=tensor([43, 43, 51,  5, 42,  1, 40, 59]) taget=56
# input=tensor([45]) taget=50
# input=tensor([45, 50]) taget=63
# input=tensor([45, 50, 63]) taget=1
# input=tensor([45, 50, 63,  1]) taget=52
# input=tensor([45, 50, 63,  1, 52]) taget=53
# input=tensor([45, 50, 63,  1, 52, 53]) taget=61
# input=tensor([45, 50, 63,  1, 52, 53, 61]) taget=12
# input=tensor([45, 50, 63,  1, 52, 53, 61, 12]) taget=0
# input=tensor([52]) taget=53
# input=tensor([52, 53]) taget=58
# input=tensor([52, 53, 58]) taget=8
# input=tensor([52, 53, 58,  8]) taget=0
# input=tensor([52, 53, 58,  8,  0]) taget=25
# input=tensor([52, 53, 58,  8,  0, 25]) taget=63
# input=tensor([52, 53, 58,  8,  0, 25, 63]) taget=1
# input=tensor([52, 53, 58,  8,  0, 25, 63,  1]) taget=61
# input=tensor([53]) taget=58
# input=tensor([53, 58]) taget=6
# input=tensor([53, 58,  6]) taget=1
# input=tensor([53, 58,  6,  1]) taget=51
# input=tensor([53, 58,  6,  1, 51]) taget=63
# input=tensor([53, 58,  6,  1, 51, 63]) taget=1
# input=tensor([53, 58,  6,  1, 51, 63,  1]) taget=50
# input=tensor([53, 58,  6,  1, 51, 63,  1, 50]) taget=53
# tensor([[24, 43, 58,  5, 57,  1, 46, 43],
#         [44, 53, 56,  1, 58, 46, 39, 58],
#         [52, 58,  1, 58, 46, 39, 58,  1],
#         [25, 17, 27, 10,  0, 21,  1, 54],
#         [57, 43, 60, 43, 52,  1, 63, 43],
#         [60, 43, 42,  8,  0, 25, 63,  1],
#         [56, 42,  5, 57,  1, 57, 39, 49],
#         [43, 57, 58, 63,  6,  1, 58, 46],
#         [43,  1, 51, 39, 63,  1, 40, 43],
#         [58, 46, 43,  1, 43, 39, 56, 57],
#         [39, 58, 47, 53, 52, 12,  1, 37],
#         [53, 56, 43,  1, 21,  1, 41, 39],
#         [50, 39, 52, 63,  1, 47, 58, 57],
#         [56, 53, 63,  1, 42, 47, 42,  1],
#         [39, 51,  1, 39, 44, 56, 39, 47],
#         [17, 24, 21, 38, 13, 14, 17, 32],
#         [ 1, 39, 52, 42,  1, 45, 43, 50],
#         [ 1, 58, 46, 39, 58,  1, 42, 53],
#         [ 1, 61, 53, 59, 50, 42,  1, 21],
#         [59, 57, 40, 39, 52, 42,  1, 40],
#         [52, 42,  8,  0,  0, 23, 21, 26],
#         [45, 53, 42, 57,  0, 23, 43, 43],
#         [52,  1, 61, 39, 57,  1, 51, 53],
#         [39, 49, 12,  1, 27,  1, 58, 56],
#         [53, 44,  1, 57, 54, 43, 43, 41],
#         [57, 53, 52, 57,  8,  0,  0, 25],
#         [ 1, 42, 43, 44, 43, 41, 58,  1],
#         [21,  1, 61, 39, 52, 42, 43, 56],
#         [43, 43, 51,  5, 42,  1, 40, 59],
#         [45, 50, 63,  1, 52, 53, 61, 12],
#         [52, 53, 58,  8,  0, 25, 63,  1],
#         [53, 58,  6,  1, 51, 63,  1, 50]])
# torch.Size([256, 65])
# tensor(4.1861, grad_fn=<NllLossBackward0>)
# step 0: train loss 4.1996, val loss 4.1995
# step 1000: train loss 2.4649, val loss 2.4756
# step 2000: train loss 2.3525, val loss 2.3559
# step 3000: train loss 2.2761, val loss 2.2886
# step 4000: train loss 2.2351, val loss 2.2626
# step 5000: train loss 2.2245, val loss 2.2335
# step 6000: train loss 2.1910, val loss 2.2232
# step 7000: train loss 2.1725, val loss 2.2265
# step 8000: train loss 2.1608, val loss 2.1854
# step 9000: train loss 2.1691, val loss 2.1908
# step 10000: train loss 2.1477, val loss 2.1802
# step 11000: train loss 2.1448, val loss 2.1788
# step 12000: train loss 2.1309, val loss 2.1750
# step 13000: train loss 2.1095, val loss 2.1734
# step 14000: train loss 2.1183, val loss 2.1664
# step 15000: train loss 2.1035, val loss 2.1662
# step 16000: train loss 2.1177, val loss 2.1646
# step 17000: train loss 2.0851, val loss 2.1602
# step 18000: train loss 2.0936, val loss 2.1455
# step 19000: train loss 2.0992, val loss 2.1638
# step 20000: train loss 2.0787, val loss 2.1683
# step 21000: train loss 2.0902, val loss 2.1587
# step 22000: train loss 2.0758, val loss 2.1514
# step 23000: train loss 2.0717, val loss 2.1500
# step 24000: train loss 2.0726, val loss 2.1461
# step 25000: train loss 2.0762, val loss 2.1558
# step 26000: train loss 2.0791, val loss 2.1481
# step 27000: train loss 2.0739, val loss 2.1428
# step 28000: train loss 2.0481, val loss 2.1401
# step 29000: train loss 2.0650, val loss 2.1400
# step 30000: train loss 2.0565, val loss 2.1492
# step 31000: train loss 2.0631, val loss 2.1505
# step 32000: train loss 2.0456, val loss 2.1451
# step 33000: train loss 2.0612, val loss 2.1467
# step 34000: train loss 2.0670, val loss 2.1377
# step 35000: train loss 2.0553, val loss 2.1464
# step 36000: train loss 2.0466, val loss 2.1296
# step 37000: train loss 2.0568, val loss 2.1338
# step 38000: train loss 2.0470, val loss 2.1491
# step 39000: train loss 2.0363, val loss 2.1356
# step 40000: train loss 2.0302, val loss 2.1380
# step 41000: train loss 2.0379, val loss 2.1408
# step 42000: train loss 2.0285, val loss 2.1402
# step 43000: train loss 2.0209, val loss 2.1330
# step 44000: train loss 2.0254, val loss 2.1296
# step 45000: train loss 2.0347, val loss 2.1449
# step 46000: train loss 2.0232, val loss 2.1361
# step 47000: train loss 2.0336, val loss 2.1342
# step 48000: train loss 2.0371, val loss 2.1288
# step 49000: train loss 2.0330, val loss 2.1453
# step 50000: train loss 2.0251, val loss 2.1326
# step 51000: train loss 2.0357, val loss 2.1319
# step 52000: train loss 2.0180, val loss 2.1254
# step 53000: train loss 2.0214, val loss 2.1327
# step 54000: train loss 2.0175, val loss 2.1341
# step 55000: train loss 2.0230, val loss 2.1310
# step 56000: train loss 2.0337, val loss 2.1337
# step 57000: train loss 2.0264, val loss 2.1350
# step 58000: train loss 2.0285, val loss 2.1330
# step 59000: train loss 2.0123, val loss 2.1332
# step 60000: train loss 2.0202, val loss 2.1297
# step 61000: train loss 2.0251, val loss 2.1302
# step 62000: train loss 2.0130, val loss 2.1252
# step 63000: train loss 2.0085, val loss 2.1106
# step 64000: train loss 2.0202, val loss 2.1332
# step 65000: train loss 2.0062, val loss 2.1356
# step 66000: train loss 2.0107, val loss 2.1360
# step 67000: train loss 2.0098, val loss 2.1189
# step 68000: train loss 2.0073, val loss 2.1396
# step 69000: train loss 2.0064, val loss 2.1297
# step 70000: train loss 2.0113, val loss 2.1406
# step 71000: train loss 2.0160, val loss 2.1361
# step 72000: train loss 2.0021, val loss 2.1283
# step 73000: train loss 2.0071, val loss 2.1278
# step 74000: train loss 2.0143, val loss 2.1369
# step 75000: train loss 2.0086, val loss 2.1271
# step 76000: train loss 1.9974, val loss 2.1260
# step 77000: train loss 2.0013, val loss 2.1292
# step 78000: train loss 2.0097, val loss 2.1276
# step 79000: train loss 1.9996, val loss 2.1222
# step 80000: train loss 2.0115, val loss 2.1289
# step 81000: train loss 2.0196, val loss 2.1236
# step 82000: train loss 2.0113, val loss 2.1238
# step 83000: train loss 2.0048, val loss 2.1147
# step 84000: train loss 1.9916, val loss 2.1341
# step 85000: train loss 2.0063, val loss 2.1111
# step 86000: train loss 2.0073, val loss 2.1210
# step 87000: train loss 2.0085, val loss 2.1256
# step 88000: train loss 2.0062, val loss 2.1401
# step 89000: train loss 2.0119, val loss 2.1239
# step 90000: train loss 2.0026, val loss 2.1155
# step 91000: train loss 1.9989, val loss 2.1235
# step 92000: train loss 1.9976, val loss 2.1204
# step 93000: train loss 2.0055, val loss 2.1153
# step 94000: train loss 2.0075, val loss 2.1282
# step 95000: train loss 1.9910, val loss 2.1203
# step 96000: train loss 1.9909, val loss 2.1285
# step 97000: train loss 1.9914, val loss 2.1390
# step 98000: train loss 2.0019, val loss 2.1205
# step 99000: train loss 1.9964, val loss 2.1259
#
#
# BOLIXETR:
# So say wath sebled-pran the look of the, sorets duch the now; yese peothy you sees wor brothe rusifor' no heak with che mast know thers is my ruck'ses as folokes arnoughter, thy busks.
# That

# %%
#generate
context = torch.zeros((1,1), dtype=torch.long, device = device)
print(decode(model.generate(context, max_new_tokens=500)[0].tolist()))
# Out:
# He my hat vainress dooupan may pesot usaity and wha with froe,
# What gat wornow
# Ats age as of tlantio ther's our, on touse; it not herend sinnt:
# A in nearbery of
# ouard seend more coer my solece, whill'd we it rainess!
# Thy heand the that by at you the theave you purilf in theess: thou do det: andizesencerver theng's I me
# advedsioure heepich heake doth, wrest bed upoill, ther be wick; in dents of say despath to befe,
# IcI wreall it beved;
# Worite, sonicesed notheeeest uchour'st, 'd intservaine, roave

# %%
def chat(model, max_new_tokens=200):
    model.eval() # Set model to evaluation mode
    print("--- Start Chatting! Type 'quit' or 'exit' to stop ---")

    while True:
        user_input = input("\nYou: ")
        if user_input.lower() in ['quit', 'exit']:
            print("Ending chat...")
            break

        if not user_input.strip():
            continue

        # Filter out characters that aren't in the trained vocabulary
        filtered_input = ''.join([c for c in user_input if c in stoi])

        if not filtered_input:
            print("Bot: (Error - input contains no characters from the model's vocabulary)")
            continue

        # Encode user input and convert to tensor on the proper device
        context = torch.tensor([encode(filtered_input)], dtype=torch.long, device=device)

        # Generate completion
        with torch.no_grad():
            # generate returns input_tokens + generated_tokens
            out_tokens = model.generate(context, max_new_tokens=max_new_tokens)[0].tolist()

        # Decode full response
        response = decode(out_tokens)

        # Print the response (you can choose to print full text or just the completion)
        print(f"Bot: {response}")

# Call the function after training your model
chat(model, max_new_tokens=150)
# Out:
# --- Start Chatting! Type 'quit' or 'exit' to stop ---
#
# You: hi
# Bot: his priair with for ands all it himssled mardserm'd; ones,
# Ther, ove! unarms, and sly'd to pas ot wipes, him. Way king now han, the is what news suble m
#
# You: do you know king?
# Bot: do you know king?
#
# DUKE ENVA:
# For lied, will thee,
# Is will him mung, belay. My,
# Noir,
# I oudy
# Firay: to stan gaave sees uome renespence
# Thou he
# Let is sleeighty drst be
#
# You: Queen
# Bot: Queen.
#
# MARY:
# As it heat dony
# How thou per as to So of to due,
# I tha mind trent, dereberen we nagen iares, reever his lived appers tas cay woweasy whe you
#
# You: QUEEN
# Bot: QUEENENDELILLO:
# Treeen your in
# In bele,
# So pate mails.
#
# by has bevent thy were!
#
# PUTOLANTIO:
# Tay.
#
# LUCIOMINIUS:
# Shall card ase, there, we paive-boot ther?
#
# You: :
# Bot: :
# To light tile doer!
#
# that poxecand you hat aimore and fuson!
#
# POMPERC:
# Clen chout, felverth me this uht and my thounnis net frien theevere?
#
# BENlove'
#
# You: Software
# Bot: Software tand like yead tilike?
# Fart; of the me it,
# frat a lore't and my tas her is pall
# Diland a nowsick on Slast of. For bely the dewithe deads, hade loses
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1141/3863727878.py in <cell line: 0>()
#      34
#      35 # Call the function after training your model
# ---> 36 chat(model, max_new_tokens=150)
#
# /tmp/ipykernel_1141/3863727878.py in chat(model, max_new_tokens)
#       4
#       5     while True:
# ----> 6         user_input = input("\nYou: ")
#       7         if user_input.lower() in ['quit', 'exit']:
#       8             print("Ending chat...")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
